# %% [markdown]
# ## 1. Importing Libraries

# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## 2. Reading the Data

# %%
DATA_DIR = 'data/raw'

def get_data(name):
    data_path = Path(DATA_DIR) / name
    return pd.read_csv(data_path)

# %%
noida = get_data('noidaRawExtractedPropertyDetails.csv')
greaterNoida = get_data('greaternoidaRawExtractedPropertyDetails.csv')
delhi = get_data('delhiRawExtractedPropertyDetails.csv')
gurgaon = get_data('gurgaonRawExtractedPropertyDetails.csv')

# %% [markdown]
# All the datasets have the same number of columns, and they are from different regions. So, to create a master DataFrame, I need to add a new column that contains the names of the regions and then concatenate all the datasets into one

# %%
noida['region'] = 'noida'
greaterNoida['region'] = 'greaterNoida'
delhi['region'] = 'delhi'
gurgaon['region'] = 'gurgaon'

# %%
df = pd.concat([noida, greaterNoida, delhi, gurgaon], ignore_index=True)

# %%
df.head()
# Out:
#                     localityName  \
# 0  Sector 108, Noida Express Way
# 1                      Sector 76
# 2                     Sector 118
# 3                      Sector 29
# 4          Sector 49, Dadri Road
#
#                                            landMarks    locality       price  \
# 0  well developed area with all facilities near s...  Sector 108  17325000.0
# 1     450 Meters from Metro Station.Facing Main Road   Sector 76  15000000.0
# 2                                                NaN  Sector 118   3950000.0
# 3                           Near Brahmaputra Market.   Sector 29  25000000.0
# 4                                                NaN   Sector 49   4300000.0
#
#            nameOfSociety            projectName carpetArea coveredArea  \
# 0          Parx Laureate          Parx Laureate       3080        3850
# 1  Amrapali Silicon City  Amrapali Silicon City       1180        1180
# 2                    NaN                    NaN        NaN        1005
# 3  Brahmaputra Apartment  Brahmaputra Apartment       1500        1800
# 4   Project Hindon Vihar   Project Hindon Vihar        NaN        1050
#
#   coveredAreaUnit carpetAreaSqft possessionStatus floorNumber  \
# 0           Sq-ft          5,625    Ready to Move           7
# 1           Sq-ft         12,712    Ready to Move           9
# 2           Sq-ft            NaN    Ready to Move         NaN
# 3           Sq-ft         16,667    Ready to Move           1
# 4           Sq-ft            NaN    Ready to Move           1
#
#   totalFloorNumber  longitude   latitude transactionType        facing  \
# 0             18.0  77.376600  28.526756          Resale  North - East
# 1             13.0  77.377500  28.568478    New Property          East
# 2              NaN  77.404719  28.582315          Resale           NaN
# 3              3.0  77.332412  28.569737          Resale  North - East
# 4              4.0  77.374460  28.560053          Resale  North - East
#
#   ownershipType       furnished bedrooms bathrooms numberOfBalconied  \
# 0     Leasehold       Furnished        4         4               NaN
# 1      Freehold       Furnished        2         2                 2
# 2     Leasehold  Semi-Furnished        2         2               NaN
# 3     Leasehold     Unfurnished        3         3                 2
# 4      Freehold     Unfurnished        3         3                 1
#
#               propertyType                        additionalRooms  \
# 0    Multistorey Apartment         Puja Room, Store, Servant Room
# 1    Multistorey Apartment                                  Study
# 2    Multistorey Apartment                                    NaN
# 3    Multistorey Apartment  Puja Room, Study, Store, Servant Room
# 4  Builder Floor Apartment                              Puja Room
#
#            ageofcons isVerified   listingTypeDesc  \
# 0                NaN          N  Standard Listing
# 1  Less than 5 years          O          Standard
# 2                NaN          O  Standard Listing
# 3     15 to 20 years          N    Prime Listings
# 4                NaN          O  Standard Listing
#
#                                    propertyAmenities  \
# 0  {'12201': 'Power Back Up', '12202': 'Lift', '1...
# 1  {'12202': 'Lift', '12203': 'Rain Water Harvest...
# 2                                                NaN
# 3  {'12203': 'Rain Water Harvesting', '12204': 'C...
# 4  {'12213': 'Vaastu Compliant', '12215': 'Air Co...
#
#                                       facilitiesDesc  propertyId  \
# 0  Power Back Up, Lift, Rain Water Harvesting, Cl...    10446116
# 1  Lift, Rain Water Harvesting, Club House, Park,...    10714088
# 2                                                NaN    11361681
# 3  Rain Water Harvesting, Club House, Swimming Po...    11376982
# 4  Vaastu Compliant, Air Conditioned, Visitor Par...    12494130
#
#                                                  url region
# 0  https://www.magicbricks.com/propertyDetails/4-...  noida
# 1  https://www.magicbricks.com/propertyDetails/2-...  noida
# 2  https://www.magicbricks.com/propertyDetails/2-...  noida
# 3  https://www.magicbricks.com/propertyDetails/3-...  noida
# 4  https://www.magicbricks.com/propertyDetails/3-...  noida

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59669 entries, 0 to 59668
# Data columns (total 32 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   localityName       58175 non-null  object
#  1   landMarks          35577 non-null  object
#  2   locality           58288 non-null  object
#  3   price              58649 non-null  float64
#  4   nameOfSociety      37269 non-null  object
#  5   projectName        37241 non-null  object
#  6   carpetArea         35974 non-null  object
#  7   coveredArea        57626 non-null  object
#  8   coveredAreaUnit    57629 non-null  object
#  9   carpetAreaSqft     35969 non-null  object
#  10  possessionStatus   49254 non-null  object
#  11  floorNumber        48814 non-null  object
#  12  totalFloorNumber   53205 non-null  object
#  13  longitude          58296 non-null  float64
#  14  latitude           58296 non-null  float64
#  15  transactionType    59652 non-null  object
#  16  facing             40648 non-null  object
#  17  ownershipType      42294 non-null  object
#  18  furnished          58704 non-null  object
#  19  bedrooms           59666 non-null  object
#  20  bathrooms          59569 non-null  object
#  21  numberOfBalconied  51811 non-null  object
#  22  propertyType       59669 non-null  object
#  23  additionalRooms    35979 non-null  object
#  24  ageofcons          52070 non-null  object
#  25  isVerified         59658 non-null  object
#  26  listingTypeDesc    59669 non-null  object
#  27  propertyAmenities  42911 non-null  object
#  28  facilitiesDesc     42911 non-null  object
#  29  propertyId         59669 non-null  int64
#  30  url                59654 non-null  object
#  31  region             59669 non-null  object
# dtypes: float64(3), int64(1), object(28)
# memory usage: 14.6+ MB

# %% [markdown]
# - The dataset contains 59669 rows and 31 columns.
# - Plenty of columns have missing values.
# - The data types of some features isn't appropriate

# %% [markdown]
# ## 3. Preliminary Analysis

# %% [markdown]
# ### 3.1 Check data types

# %%
df.dtypes
# Out:
# localityName          object
# landMarks             object
# locality              object
# price                float64
# nameOfSociety         object
# projectName           object
# carpetArea            object
# coveredArea           object
# coveredAreaUnit       object
# carpetAreaSqft        object
# possessionStatus      object
# floorNumber           object
# totalFloorNumber      object
# longitude            float64
# latitude             float64
# transactionType       object
# facing                object
# ownershipType         object
# furnished             object
# bedrooms              object
# bathrooms             object
# numberOfBalconied     object
# propertyType          object
# additionalRooms       object
# ageofcons             object
# isVerified            object
# listingTypeDesc       object
# propertyAmenities     object
# facilitiesDesc        object
# propertyId             int64
# url                   object
# region                object
# dtype: object

# %% [markdown]
# -  Some columns such as `carpetArea, coveredArea, carpetAreaSqft, floorNumber, totalFloorNumber, bedrooms, bathrooms, and numberOfBalconied` have an object data type. They need to be converted to an integer data type

# %% [markdown]
# ### 3.2 Check for Duplicates

# %%
df.duplicated().sum() # There are no duplicates.
# Out:
# np.int64(0)

# %% [markdown]
# ## 4. Detailed Analysis

# %%
df.locality.nunique()
# Out:
# 2487

# %%
df.head()
# Out:
#                     localityName  \
# 0  Sector 108, Noida Express Way
# 1                      Sector 76
# 2                     Sector 118
# 3                      Sector 29
# 4          Sector 49, Dadri Road
#
#                                            landMarks    locality       price  \
# 0  well developed area with all facilities near s...  Sector 108  17325000.0
# 1     450 Meters from Metro Station.Facing Main Road   Sector 76  15000000.0
# 2                                                NaN  Sector 118   3950000.0
# 3                           Near Brahmaputra Market.   Sector 29  25000000.0
# 4                                                NaN   Sector 49   4300000.0
#
#            nameOfSociety            projectName carpetArea coveredArea  \
# 0          Parx Laureate          Parx Laureate       3080        3850
# 1  Amrapali Silicon City  Amrapali Silicon City       1180        1180
# 2                    NaN                    NaN        NaN        1005
# 3  Brahmaputra Apartment  Brahmaputra Apartment       1500        1800
# 4   Project Hindon Vihar   Project Hindon Vihar        NaN        1050
#
#   coveredAreaUnit carpetAreaSqft possessionStatus floorNumber  \
# 0           Sq-ft          5,625    Ready to Move           7
# 1           Sq-ft         12,712    Ready to Move           9
# 2           Sq-ft            NaN    Ready to Move         NaN
# 3           Sq-ft         16,667    Ready to Move           1
# 4           Sq-ft            NaN    Ready to Move           1
#
#   totalFloorNumber  longitude   latitude transactionType        facing  \
# 0             18.0  77.376600  28.526756          Resale  North - East
# 1             13.0  77.377500  28.568478    New Property          East
# 2              NaN  77.404719  28.582315          Resale           NaN
# 3              3.0  77.332412  28.569737          Resale  North - East
# 4              4.0  77.374460  28.560053          Resale  North - East
#
#   ownershipType       furnished bedrooms bathrooms numberOfBalconied  \
# 0     Leasehold       Furnished        4         4               NaN
# 1      Freehold       Furnished        2         2                 2
# 2     Leasehold  Semi-Furnished        2         2               NaN
# 3     Leasehold     Unfurnished        3         3                 2
# 4      Freehold     Unfurnished        3         3                 1
#
#               propertyType                        additionalRooms  \
# 0    Multistorey Apartment         Puja Room, Store, Servant Room
# 1    Multistorey Apartment                                  Study
# 2    Multistorey Apartment                                    NaN
# 3    Multistorey Apartment  Puja Room, Study, Store, Servant Room
# 4  Builder Floor Apartment                              Puja Room
#
#            ageofcons isVerified   listingTypeDesc  \
# 0                NaN          N  Standard Listing
# 1  Less than 5 years          O          Standard
# 2                NaN          O  Standard Listing
# 3     15 to 20 years          N    Prime Listings
# 4                NaN          O  Standard Listing
#
#                                    propertyAmenities  \
# 0  {'12201': 'Power Back Up', '12202': 'Lift', '1...
# 1  {'12202': 'Lift', '12203': 'Rain Water Harvest...
# 2                                                NaN
# 3  {'12203': 'Rain Water Harvesting', '12204': 'C...
# 4  {'12213': 'Vaastu Compliant', '12215': 'Air Co...
#
#                                       facilitiesDesc  propertyId  \
# 0  Power Back Up, Lift, Rain Water Harvesting, Cl...    10446116
# 1  Lift, Rain Water Harvesting, Club House, Park,...    10714088
# 2                                                NaN    11361681
# 3  Rain Water Harvesting, Club House, Swimming Po...    11376982
# 4  Vaastu Compliant, Air Conditioned, Visitor Par...    12494130
#
#                                                  url region
# 0  https://www.magicbricks.com/propertyDetails/4-...  noida
# 1  https://www.magicbricks.com/propertyDetails/2-...  noida
# 2  https://www.magicbricks.com/propertyDetails/2-...  noida
# 3  https://www.magicbricks.com/propertyDetails/3-...  noida
# 4  https://www.magicbricks.com/propertyDetails/3-...  noida

# %%
df.localityName.nunique()
# Out:
# 2548

# %%
(
    df.localityName
    .str.lower()
    .str.strip()
)
# Out:
# 0        sector 108, noida express way
# 1                            sector 76
# 2                           sector 118
# 3                            sector 29
# 4                sector 49, dadri road
#                      ...
# 59664                        sector 49
# 59665                      phase 5 dlf
# 59666                 golf course road
# 59667                       sohna road
# 59668                        sector 14
# Name: localityName, Length: 59669, dtype: object

# %% [markdown]
# ### landMarks

# %%
df.landMarks.nunique()
# Out:
# 20196

# %% [markdown]
# ### locality

# %%
(
    df.locality
    .str.lower()
    .str.strip()
)
# Out:
# 0              sector 108
# 1               sector 76
# 2              sector 118
# 3               sector 29
# 4               sector 49
#                ...
# 59664           sector 49
# 59665         dlf phase 5
# 59666    golf course road
# 59667          sohna road
# 59668           sector 14
# Name: locality, Length: 59669, dtype: object

# %% [markdown]
# ### price
# -  convert into crores to make it more readable.

# %%
(
    df.price
    .apply(lambda x: round(int(x)/10000000,2) if not np.isnan(x) else np.nan)
)
# Out:
# 0        1.73
# 1        1.50
# 2        0.40
# 3        2.50
# 4        0.43
#          ...
# 59664    0.54
# 59665     NaN
# 59666    8.00
# 59667    7.60
# 59668    0.65
# Name: price, Length: 59669, dtype: float64

# %% [markdown]
# ### nameOfSociety

# %%
df.nameOfSociety.nunique()
# Out:
# 5058

# %%
df.nameOfSociety
# Out:
# 0                Parx Laureate
# 1        Amrapali Silicon City
# 2                          NaN
# 3        Brahmaputra Apartment
# 4         Project Hindon Vihar
#                  ...
# 59664              Vatika City
# 59665                      NaN
# 59666                      NaN
# 59667                      NaN
# 59668                      NaN
# Name: nameOfSociety, Length: 59669, dtype: object

# %% [markdown]
# ### projectName

# %%
df.projectName.nunique()
# Out:
# 3311

# %% [markdown]
# ### carpetArea

# %%
df.carpetArea.loc[df.carpetArea.astype(str).str.contains(',', na=False)]
# Out:
# 1796     11,000
# 1849     10,000
# 1852     11,000
# 1896     10,000
# 1903     10,000
#           ...
# 53738    10,000
# 54340    16,000
# 54936    10,200
# 55608    47,017
# 58403    17,550
# Name: carpetArea, Length: 72, dtype: object

# %%
(
    df.carpetArea
    .str.replace(',', '')
    .astype(int, errors='ignore')
)
# Out:
# 0        3080
# 1        1180
# 2         NaN
# 3        1500
# 4         NaN
#          ...
# 59664     NaN
# 59665     NaN
# 59666     NaN
# 59667     NaN
# 59668     NaN
# Name: carpetArea, Length: 59669, dtype: object

# %% [markdown]
# ### coveredArea
# - `coveredArea` is actually super builtup area. So, it needs to be renamed super builtup area.

# %%
df.coveredArea.loc[df.coveredArea.astype(str).str.contains(',', na=False)]
# Out:
# 618      13,500
# 699      13,500
# 930      10,500
# 1467     18,883
# 1493     10,218
#           ...
# 54936    12,000
# 56314    20,000
# 56769    22,000
# 58031    15,720
# 59019    10,000
# Name: coveredArea, Length: 139, dtype: object

# %%
(
    df.coveredArea
    .str.replace(',', '')
    .astype(int, errors='ignore')
)
# Out:
# 0        3850
# 1        1180
# 2        1005
# 3        1800
# 4        1050
#          ...
# 59664    1714
# 59665    2810
# 59666    7000
# 59667    6869
# 59668    1255
# Name: coveredArea, Length: 59669, dtype: object

# %% [markdown]
# ### coveredAreaUnit
# - `'Biswa2', 'Acre', 'Bigha', 'Hectare', 'Rood', 'Ground', 'Biswa1', 'Marla'` need to be dropped because their scales are insignificant.
# - `'Sq-m', 'Sq-yrd'` need to be converted into `Sq-ft` to maintain consistent scale.

# %%
df.coveredAreaUnit.unique()
# Out:
# array(['Sq-ft', 'Sq-m', 'Sq-yrd', nan, 'Biswa2', 'Acre', 'Bigha',
#        'Hectare', 'Rood', 'Ground', 'Biswa1', 'Marla'], dtype=object)

# %%
df.coveredAreaUnit.loc[lambda ser: ser.str.contains('Bigha', na=False)]
# Out:
# 18181    Bigha
# 44896    Bigha
# Name: coveredAreaUnit, dtype: object

# %% [markdown]
# ### possessionStatus

# %%
(
    df.possessionStatus
    .str.lower()
    .str.strip()
)
# Out:
# 0        ready to move
# 1        ready to move
# 2        ready to move
# 3        ready to move
# 4        ready to move
#              ...
# 59664              NaN
# 59665    ready to move
# 59666    ready to move
# 59667              NaN
# 59668    ready to move
# Name: possessionStatus, Length: 59669, dtype: object

# %% [markdown]
# ### floorNumber

# %%
(
  df.floorNumber.astype(str)  
)
# Out:
# 0          7
# 1          9
# 2        nan
# 3          1
# 4          1
#         ...
# 59664      8
# 59665    nan
# 59666    nan
# 59667    nan
# 59668      1
# Name: floorNumber, Length: 59669, dtype: object

# %% [markdown]
# ### totalFloorNumber

# %%
(
    pd.to_numeric(df.totalFloorNumber, errors='coerce')
)
# Out:
# 0        18.0
# 1        13.0
# 2         NaN
# 3         3.0
# 4         4.0
#          ...
# 59664    14.0
# 59665     NaN
# 59666     NaN
# 59667     NaN
# 59668     3.0
# Name: totalFloorNumber, Length: 59669, dtype: float64

# %% [markdown]
# ### transactionType

# %%
(
    df.transactionType
    .str.lower()
    .str.strip()
)
# Out:
# 0              resale
# 1        new property
# 2              resale
# 3              resale
# 4              resale
#              ...
# 59664    new property
# 59665          resale
# 59666          resale
# 59667          resale
# 59668          resale
# Name: transactionType, Length: 59669, dtype: object

# %% [markdown]
# ### facing

# %%
(
    df.facing
    .str.lower()
    .str.strip()
)
# Out:
# 0        north - east
# 1                east
# 2                 NaN
# 3        north - east
# 4        north - east
#              ...
# 59664            east
# 59665            east
# 59666             NaN
# 59667             NaN
# 59668            east
# Name: facing, Length: 59669, dtype: object

# %% [markdown]
# ### ownershipType

# %%
(
    df.ownershipType
    .str.lower()
    .str.strip()
)
# Out:
# 0        leasehold
# 1         freehold
# 2        leasehold
# 3        leasehold
# 4         freehold
#            ...
# 59664     freehold
# 59665     freehold
# 59666     freehold
# 59667     freehold
# 59668     freehold
# Name: ownershipType, Length: 59669, dtype: object

# %% [markdown]
# ### furnished

# %%
(
    df.furnished
    .str.lower()
    .str.strip()
)
# Out:
# 0             furnished
# 1             furnished
# 2        semi-furnished
# 3           unfurnished
# 4           unfurnished
#               ...
# 59664    semi-furnished
# 59665         furnished
# 59666    semi-furnished
# 59667       unfurnished
# 59668    semi-furnished
# Name: furnished, Length: 59669, dtype: object

# %% [markdown]
# ### bedrooms

# %%
(
   pd.to_numeric(df.bedrooms, errors='coerce')
)
# Out:
# 0        4.0
# 1        2.0
# 2        2.0
# 3        3.0
# 4        3.0
#         ...
# 59664    3.0
# 59665    5.0
# 59666    5.0
# 59667    5.0
# 59668    2.0
# Name: bedrooms, Length: 59669, dtype: float64

# %% [markdown]
# ### bathrooms

# %%
(
   pd.to_numeric(df.bathrooms, errors='coerce')
)
# Out:
# 0        4.0
# 1        2.0
# 2        2.0
# 3        3.0
# 4        3.0
#         ...
# 59664    2.0
# 59665    5.0
# 59666    5.0
# 59667    7.0
# 59668    3.0
# Name: bathrooms, Length: 59669, dtype: float64

# %% [markdown]
# ### numberOfBalconied

# %%
(
   pd.to_numeric(df.numberOfBalconied, errors='coerce')
)
# Out:
# 0        NaN
# 1        2.0
# 2        NaN
# 3        2.0
# 4        1.0
#         ...
# 59664    2.0
# 59665    NaN
# 59666    NaN
# 59667    NaN
# 59668    2.0
# Name: numberOfBalconied, Length: 59669, dtype: float64

# %% [markdown]
# ### propertyType

# %%
(
    df.propertyType
    .str.lower()
    .str.strip()
)
# Out:
# 0          multistorey apartment
# 1          multistorey apartment
# 2          multistorey apartment
# 3          multistorey apartment
# 4        builder floor apartment
#                   ...
# 59664      multistorey apartment
# 59665      multistorey apartment
# 59666      multistorey apartment
# 59667          residential house
# 59668    builder floor apartment
# Name: propertyType, Length: 59669, dtype: object

# %% [markdown]
# ### additionalRooms

# %%
(
    df.additionalRooms
    .str.lower()
    .str.strip()
)
# Out:
# 0               puja room, store, servant room
# 1                                        study
# 2                                          NaN
# 3        puja room, study, store, servant room
# 4                                    puja room
#                          ...
# 59664                                      NaN
# 59665                             servant room
# 59666                                      NaN
# 59667                             servant room
# 59668                                      NaN
# Name: additionalRooms, Length: 59669, dtype: object

# %% [markdown]
# ### ageofcons

# %%
(
    df['ageofcons']
    .str.lower()
)
# Out:
# 0                       NaN
# 1         less than 5 years
# 2                       NaN
# 3            15 to 20 years
# 4                       NaN
#                 ...
# 59664    under construction
# 59665                   NaN
# 59666                   NaN
# 59667    under construction
# 59668                   NaN
# Name: ageofcons, Length: 59669, dtype: object

# %%
df['listingTypeDesc'].value_counts()
# Out:
# listingTypeDesc
# Prime Listings           17639
# Premium                  16833
# Standard Listing          7457
# Standard                  7452
# Certified Listing         7022
# Titanium                  2901
# Platinum                   330
# Premium Plus Listings       32
# Premium Listing              3
# Name: count, dtype: int64

# %%
df.head()
# Out:
#                     localityName  \
# 0  Sector 108, Noida Express Way
# 1                      Sector 76
# 2                     Sector 118
# 3                      Sector 29
# 4          Sector 49, Dadri Road
#
#                                            landMarks    locality       price  \
# 0  well developed area with all facilities near s...  Sector 108  17325000.0
# 1     450 Meters from Metro Station.Facing Main Road   Sector 76  15000000.0
# 2                                                NaN  Sector 118   3950000.0
# 3                           Near Brahmaputra Market.   Sector 29  25000000.0
# 4                                                NaN   Sector 49   4300000.0
#
#            nameOfSociety            projectName carpetArea coveredArea  \
# 0          Parx Laureate          Parx Laureate       3080        3850
# 1  Amrapali Silicon City  Amrapali Silicon City       1180        1180
# 2                    NaN                    NaN        NaN        1005
# 3  Brahmaputra Apartment  Brahmaputra Apartment       1500        1800
# 4   Project Hindon Vihar   Project Hindon Vihar        NaN        1050
#
#   coveredAreaUnit carpetAreaSqft possessionStatus floorNumber  \
# 0           Sq-ft          5,625    Ready to Move           7
# 1           Sq-ft         12,712    Ready to Move           9
# 2           Sq-ft            NaN    Ready to Move         NaN
# 3           Sq-ft         16,667    Ready to Move           1
# 4           Sq-ft            NaN    Ready to Move           1
#
#   totalFloorNumber  longitude   latitude transactionType        facing  \
# 0             18.0  77.376600  28.526756          Resale  North - East
# 1             13.0  77.377500  28.568478    New Property          East
# 2              NaN  77.404719  28.582315          Resale           NaN
# 3              3.0  77.332412  28.569737          Resale  North - East
# 4              4.0  77.374460  28.560053          Resale  North - East
#
#   ownershipType       furnished bedrooms bathrooms numberOfBalconied  \
# 0     Leasehold       Furnished        4         4               NaN
# 1      Freehold       Furnished        2         2                 2
# 2     Leasehold  Semi-Furnished        2         2               NaN
# 3     Leasehold     Unfurnished        3         3                 2
# 4      Freehold     Unfurnished        3         3                 1
#
#               propertyType                        additionalRooms  \
# 0    Multistorey Apartment         Puja Room, Store, Servant Room
# 1    Multistorey Apartment                                  Study
# 2    Multistorey Apartment                                    NaN
# 3    Multistorey Apartment  Puja Room, Study, Store, Servant Room
# 4  Builder Floor Apartment                              Puja Room
#
#            ageofcons isVerified   listingTypeDesc  \
# 0                NaN          N  Standard Listing
# 1  Less than 5 years          O          Standard
# 2                NaN          O  Standard Listing
# 3     15 to 20 years          N    Prime Listings
# 4                NaN          O  Standard Listing
#
#                                    propertyAmenities  \
# 0  {'12201': 'Power Back Up', '12202': 'Lift', '1...
# 1  {'12202': 'Lift', '12203': 'Rain Water Harvest...
# 2                                                NaN
# 3  {'12203': 'Rain Water Harvesting', '12204': 'C...
# 4  {'12213': 'Vaastu Compliant', '12215': 'Air Co...
#
#                                       facilitiesDesc  propertyId  \
# 0  Power Back Up, Lift, Rain Water Harvesting, Cl...    10446116
# 1  Lift, Rain Water Harvesting, Club House, Park,...    10714088
# 2                                                NaN    11361681
# 3  Rain Water Harvesting, Club House, Swimming Po...    11376982
# 4  Vaastu Compliant, Air Conditioned, Visitor Par...    12494130
#
#                                                  url region
# 0  https://www.magicbricks.com/propertyDetails/4-...  noida
# 1  https://www.magicbricks.com/propertyDetails/2-...  noida
# 2  https://www.magicbricks.com/propertyDetails/2-...  noida
# 3  https://www.magicbricks.com/propertyDetails/3-...  noida
# 4  https://www.magicbricks.com/propertyDetails/3-...  noida

# %% [markdown]
# ## Cleaning Operations

# %%
def convert_to_sqft(coveredArea, coveredAreaUnit):
    if pd.isna(coveredArea):
        return np.nan
    try:
        value = float(str(coveredArea).replace(',', ''))
    except ValueError:
        return np.nan
    if coveredAreaUnit == 'Sq-yrd':
        return value * 9
    elif coveredAreaUnit == 'Sq-m':
        return round(value * 10.7639, 2)
    elif coveredAreaUnit == 'Sq-ft':
        return value
    else:
        return np.nan

def change_scale(coveredAreaUnit):
    if coveredAreaUnit in ['sq-yrd', 'sq-m', 'sq-ft']:
        return 'sq-ft'
    else:
        return np.nan

# %%
def clean_data(df):
    return (
        df.rename(columns=str.lower)
        .assign(
            localityname= lambda df_: (df_.localityname
                            .str.lower()
                            .str.strip()
        ),
            landmarks= lambda df_: (df_.landmarks
                            .str.lower()
                            .str.strip()
        ),
            locality= lambda df_: (df_.locality
                            .str.lower()
                            .str.strip()
        ),
            nameofsociety = lambda df_: (df_.nameofsociety
                            .str.lower()
                            .str.strip()
        ),
            price= lambda df_: pd.to_numeric(df_.price, errors='coerce'),
            coveredarea= lambda df_: pd.to_numeric(df_.coveredarea, errors='coerce'),
            carpetarea= lambda df_: pd.to_numeric(df_.carpetarea, errors='coerce'),
            superbuiltuparea = lambda df_ : df_.apply(
                lambda row: convert_to_sqft(row.coveredarea, row.coveredareaunit),
                axis=1
            ),
             coveredareaunit= lambda df_: (df_.coveredareaunit
                            .str.lower()
                            .str.strip().apply(change_scale)
        ),
             possessionstatus= lambda df_: (df_.possessionstatus
                            .str.lower()
                            .str.strip()
        ),
             floornumber= lambda df_: df_.floornumber.astype(str),
             totalfloornumber= lambda df_: pd.to_numeric(df_.totalfloornumber, errors='coerce'),
             transactiontype= lambda df_: (df_.transactiontype
                            .str.lower()
                            .str.strip()
        ),
             facing= lambda df_: (df_.facing
                            .str.lower()
                            .str.strip()
        ),  
             ownershiptype= lambda df_: (df_.ownershiptype
                            .str.lower()
                            .str.strip()
        ),
             furnished = lambda df_: (df_.furnished
                            .str.lower()
                            .str.strip()
        ),
             bedrooms= lambda df_: pd.to_numeric(df_.bedrooms, errors='coerce'),
             bathrooms= lambda df_: pd.to_numeric(df_.bathrooms, errors='coerce'),
             numberofbalconied= lambda df_: pd.to_numeric(df_.numberofbalconied, errors='coerce'),
             propertytype= lambda df_: (df_.propertytype
                            .str.lower()
                            .str.strip()
        ),
             additionalrooms= lambda df_: (df_.additionalrooms
                            .str.lower()
                            .str.strip()
        ),
             ageofcons = lambda df_: (df_.ageofcons
                            .str.lower()
                            .str.strip()
        ),
        
    ).drop(columns=['carpetarea','carpetareasqft', 'isverified', 'listingtypedesc'])
     .pipe(lambda df_: df_.loc[df_.superbuiltuparea > 450])
     .dropna(subset=['price'])
     .reset_index(drop=True)
     
    )

# %%
cleaned_df = clean_data(df)

# %%
cleaned_df.shape
# Out:
# (54956, 29)

# %%
cleaned_df.to_csv('data/raw/cleaned_dataV1.csv', index=False)

# %%
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54956 entries, 0 to 54955
# Data columns (total 29 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   localityname       53710 non-null  object
#  1   landmarks          33771 non-null  object
#  2   locality           53807 non-null  object
#  3   price              54956 non-null  float64
#  4   nameofsociety      35511 non-null  object
#  5   projectname        35486 non-null  object
#  6   coveredarea        54956 non-null  float64
#  7   coveredareaunit    54956 non-null  object
#  8   possessionstatus   45203 non-null  object
#  9   floornumber        54956 non-null  object
#  10  totalfloornumber   48917 non-null  float64
#  11  longitude          53819 non-null  float64
#  12  latitude           53819 non-null  float64
#  13  transactiontype    54952 non-null  object
#  14  facing             38339 non-null  object
#  15  ownershiptype      39716 non-null  object
#  16  furnished          54137 non-null  object
#  17  bedrooms           54803 non-null  float64
#  18  bathrooms          54781 non-null  float64
#  19  numberofbalconied  48263 non-null  float64
#  20  propertytype       54956 non-null  object
#  21  additionalrooms    34101 non-null  object
#  22  ageofcons          48241 non-null  object
#  23  propertyamenities  40493 non-null  object
#  24  facilitiesdesc     40493 non-null  object
#  25  propertyid         54956 non-null  int64
#  26  url                54951 non-null  object
#  27  region             54956 non-null  object
#  28  superbuiltuparea   54956 non-null  float64
# dtypes: float64(9), int64(1), object(19)
# memory usage: 12.2+ MB
